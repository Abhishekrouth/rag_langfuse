# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
metrics = {
    "answer_relevancy": 0.7615,
    "faithfulness": 1.00,
    "context_precision":1.00,
    "context_recall": 1.00
}

# %%
df= pd.DataFrame([metrics])
print("Detailed Metric Breakdown:\n", df)
# Out:
# Detailed Metric Breakdown:
#     answer_relevancy  faithfulness  context_precision  context_recall
# 0            0.7615           1.0                1.0             1.0

# %%
plt.figure(figsize=(7, 4))
plt.bar(metrics.keys(), metrics.values(), color=["#A50E0E", "#24BA62", "#653F03", "#00B69A"], edgecolor='black')

plt.title("RAGAS Evaluation Summary", fontsize=10)
plt.ylabel("Score")
plt.show()
